# %% [markdown]
# # **Jupyter Notebook_Isaac_Eliseu**
# Nesta atividade, estou aprendendo a manipular dados com Pandas através do Anaconda.
# Até agora, achei o processo de instalação um pouco complicado por estar aprendendo a interagir com a interface.
# Mas estou gostando da experiência.

# %% [markdown]
# ## *Importando a planilha para o notebook*

# %%
import pandas as pd

# %%
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# ## *Resolução questões*

# %% [markdown]
# **1. Saber quantas colunas os dados contêm. (Podem ser de características, resposta ou metadados)**

# %%
df.shape[1]
# Out:
# 25

# %% [markdown]
# *Análise (Complemento):* O conjunto de dados possui 25 colunas. Elas representam as variáveis do estudo.

# %% [markdown]
# **2. Quantas linhas (amostras).**

# %%
df.shape[0]
# Out:
# 30000

# %% [markdown]
# *Análise (Complemento):* Foram identificadas 30.000 linhas

# %% [markdown]
# **3. Que tipos de características existem. Quais são categóricas e quais são numéricas? (Os valores das características categóricas pertencem a classes discretas como “sim”, “não” ou “talvez”. Normalmente as características numéricas pertencem a uma escala numérica contínua, como as quantias em dólares).**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %% [markdown]
# *Análise (Complemento):* O dataset possui 23 colunas numéricas (do tipo int64) e 2 colunas classificadas como objetos (object), que são ID e PAY_1. Variáveis categóricas como gênero (SEX) e escolaridade (EDUCATION) já aparecem codificadas como números.

# %% [markdown]
# **4. Qual é a aparência dos dados segundo essas características. (Para saber isso, você pode examinar o intervalo de valores em características numéricas ou a frequência de classes diferentes em características categóricas, por exemplo).**

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %% [markdown]
# *Análise (Complemento):* Os limites de crédito (LIMIT_BAL) apresentam grande variação, com média de aproximadamente 165 mil e valor máximo de 1 milhão. A média de idade dos clientes é de 35 anos, atendendo a um público que chega aos 79 anos de idade.

# %% [markdown]
# **5. Existem dados faltando?**

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# *Análise (Complemento):* O dataset está completo. A verificação mostra que não há dados faltando em nenhuma das colunas
